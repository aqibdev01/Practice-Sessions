# %%
import pandas as pd

# %%
data = [1,2,3,4,5]
ser = pd.Series(data)
print(ser)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data = [1,2,3,4,5]
indices = ['a','b','c','d','e']
ser = pd.Series(data,indices)
print(ser)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
data = [True,'2','3','4','5']
ser = pd.Series(data)
print(ser)
print(type(ser))
# Out:
# 0    True
# 1       2
# 2       3
# 3       4
# 4       5
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
dict_data = {
    'name':'Aqib', 'city':'Islamabad'
}
ser = pd.Series(dict_data)
print(ser)
# Out:
# name         Aqib
# city    Islamabad
# dtype: object

# %%
# Dataframes
data = {
    'Name':['Aqib', 'Ali','Junaid'],
    'Age':[21,15,24],
    'City':['Islamabad','Abbotabad','Damam']
}
df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age       City
# 0    Aqib   21  Islamabad
# 1     Ali   15  Abbotabad
# 2  Junaid   24      Damam

# %%
import numpy as np
print(np.array(data))
# Out:
# [['Aqib' 'Ali' 'Junaid']
#  ['21' '15' '24']
#  ['Islamabad' 'Abbotabad' 'Damam']]

# %%
data =[ 
    ['Aqib', 'Ali','Junaid'],
    [21,15,24],
    ['Islamabad','Abbotabad','Damam']
]
df = pd.DataFrame(data)
print(df)
# Out:
#            0          1       2
# 0       Aqib        Ali  Junaid
# 1         21         15      24
# 2  Islamabad  Abbotabad   Damam

# %%
data = [
    {'Name': 'Aqib', 'Age':12, 'City':'Wah'},
    {'Name': 'Hello', 'Age':21, 'City':'KHI'},
    {'Name': 'Jani', 'Age':50, 'City':'Isl'},
    {'Name': 'Yapper', 'Age':33, 'City':'pak'}
]

# print(pd.DataFrame(data))

# %%
# df= pd.read_csv('sales_data.csv')
df.head(6)
# Out:
#    Transaction ID        Date Product Category                 Product Name  \
# 0           10001  2024-01-01      Electronics                iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances             Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing             Levi's 501 Jeans
# 3           10004  2024-01-04            Books            The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products      Neutrogena Skincare Set
# 5           10006  2024-01-06           Sports  Wilson Evolution Basketball
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal
# ...

# %%
data= pd.read_csv('sales_data.csv')
data.tail(6)
# Out:
#      Transaction ID        Date Product Category  \
# 234           10235  2024-08-22      Electronics
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 234      Bose QuietComfort 35 II Wireless Headphones           1      299.00
# 235  Nespresso Vertuo Next Coffee and Espresso Maker           1      159.99
# 236                        Nike Air Force 1 Sneakers           3       90.00
# 237           The Handmaid's Tale by Margaret Atwood           3       10.99
# 238             Sunday Riley Luna Sleeping Night Oil           1       55.00
# 239                       Yeti Rambler 20 oz Tumbler           2       29.99
#
#      Total Revenue         Region Payment Method
# ...

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age City
# 0    Aqib   12  Wah
# 1   Hello   21  KHI
# 2    Jani   50  Isl
# 3  Yapper   33  pak

# %%
df['Name']
# Out:
# 0      Aqib
# 1     Hello
# 2      Jani
# 3    Yapper
# Name: Name, dtype: object

# %%
print(df.loc[0:])
df.loc[1][2]
# Out:
#      Name  Age City
# 0    Aqib   12  Wah
# 1   Hello   21  KHI
# 2    Jani   50  Isl
# 3  Yapper   33  pak
# C:\Users\aqibm\AppData\Local\Temp\ipykernel_9264\1300944830.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[1][2]
# 'KHI'

# %%
df.iloc[0]
# Out:
# Name    Aqib
# Age       12
# City     Wah
# Name: 0, dtype: object

# %%
df.at[0,'City']
# Out:
# 'Wah'

# %%
df.iat[1,0]
# Out:
# 'Hello'

# %%
df
# Out:
#      Name  Age City
# 0    Aqib   12  Wah
# 1   Hello   21  KHI
# 2    Jani   50  Isl
# 3  Yapper   33  pak

# %%
df['Salary']= [1000,12000,60000,90000]
df
# Out:
#      Name  Age City  Salary
# 0    Aqib   12  Wah    1000
# 1   Hello   21  KHI   12000
# 2    Jani   50  Isl   60000
# 3  Yapper   33  pak   90000

# %% [markdown]
# # Deafult axis is zero
# in drop function which will search and drop Row set axis to 1 for droping column
# Set inplace True for maing the change permanently

# %%
df.drop('Salary',axis=1, inplace=True)
# Out:
#      Name  Age City
# 0    Aqib   12  Wah
# 1   Hello   21  KHI
# 2    Jani   50  Isl
# 3  Yapper   33  pak

# %%
data.describe()      #Shows statistical summary
# Out:
#        Transaction ID  Units Sold   Unit Price  Total Revenue
# count       240.00000  240.000000   240.000000     240.000000
# mean      10120.50000    2.158333   236.395583     335.699375
# std          69.42622    1.322454   429.446695     485.804469
# min       10001.00000    1.000000     6.500000       6.500000
# 25%       10060.75000    1.000000    29.500000      62.965000
# 50%       10120.50000    2.000000    89.990000     179.970000
# 75%       10180.25000    3.000000   249.990000     399.225000
# max       10240.00000   10.000000  3899.990000    3899.990000

# %%
df = pd.read_csv('data.csv')
df.isnull()
df.isnull().any()
df.isnull().sum()
# Out:
# Date        0
# Category    0
# Value       3
# Product     0
# Sales       4
# Region      0
# dtype: int64

# %%
df['Sales_New'] = df['Sales'].fillna(df['Sales'].mean())
df
# Out:
#           Date Category  Value   Product  Sales Region   Sales_New
# 0   2023-01-01        A   28.0  Product1  754.0   East  754.000000
# 1   2023-01-02        B   39.0  Product3  110.0  North  110.000000
# 2   2023-01-03        C   32.0  Product2  398.0   East  398.000000
# 3   2023-01-04        B    8.0  Product1  522.0   East  522.000000
# 4   2023-01-05        B   26.0  Product3  869.0  North  869.000000
# 5   2023-01-06        B   54.0  Product3  192.0   West  192.000000
# 6   2023-01-07        A   16.0  Product1  936.0   East  936.000000
# 7   2023-01-08        C   89.0  Product1  488.0   West  488.000000
# 8   2023-01-09        C   37.0  Product3  772.0   West  772.000000
# 9   2023-01-10        A   22.0  Product2  834.0   West  834.000000
# 10  2023-01-11        B    7.0  Product1  842.0  North  842.000000
# 11  2023-01-12        B   60.0  Product2    NaN   West  557.130435
# 12  2023-01-13        A   70.0  Product3  628.0  South  628.000000
# ...

# %%
df.dtypes
# Out:
# Date          object
# Category      object
# Value        float64
# Product       object
# Sales        float64
# Region        object
# Sales_New    float64
# dtype: object

# %%
df = df.rename(columns={'Date': 'Sales Date'})

# %%
df['Value_new'] = df['Value'].fillna(df['Value'].mean()).astype(int)
df.dtypes
# Out:
# Sales Date     object
# Category       object
# Value         float64
# Product        object
# Sales         float64
# Region         object
# Sales_New     float64
# Value_new       int64
# dtype: object

# %%
print(df.groupby('Region')['Value_new'].mean())
# Out:
# Region
# East     42.307692
# North    40.090909
# South    62.000000
# West     61.000000
# Name: Value_new, dtype: float64

# %%
print(df.groupby(['Region','Product'])['Value_new'].agg(['sum','count','mean']))
# Out:
#                  sum  count       mean
# Region Product
# East   Product1  292      7  41.714286
#        Product2   56      2  28.000000
#        Product3  202      4  50.500000
# North  Product1   60      3  20.000000
#        Product2  127      2  63.500000
#        Product3  254      6  42.333333
# South  Product1  100      2  50.000000
#        Product2  181      3  60.333333
#        Product3  215      3  71.666667
# West   Product1  297      4  74.250000
#        Product2  428      8  53.500000
#        Product3  373      6  62.166667
